# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import matplotlib.patches as mpatches

# %%
X_axis = np.random.seed(42)
#Y_axis = np.random.seed(42)

averageTMP = np.random.uniform(-1,5.2 , size=68).reshape((68, 1))
averagePCP = np.random.uniform(-2,10 , size=68).reshape((68, 1))

#TMP = np.reshape()

a = np.full((1,12), 2.6)
b = np.full((1,25), 4.5)
c = np.full((1,31), 8.5)
RCPs = np.concatenate((a, b, c), axis=1).reshape((68, 1))
#e = np.random.shuffle(RCPs).reshape((68, 1))
data = np.concatenate((averageTMP,averagePCP,RCPs), axis=1)
np.random.shuffle(data)

#RCPs
#e = np.random.shuffle(RCPs)
df = pd.DataFrame (data, columns = ['averageTMP','averagePCP', 'RCPs'])

# %%
#data
#df

# %%
#type(averageTMP)

# %%
#RCPs
#RCPs.shape

# %%
#averageTMP.shape

# %%
#averagePCP.shape

# %%
#data.shape

# %%
df = pd.read_csv('snowData_1.csv')
years = df.iloc [:, 0:1]
snowDays = df.iloc [:, 1:2]
#years
#snowDays

# %%
#colors = rng.rand(68)
#np.random.seed(19680801)

fig, ax = plt.subplots()
#classess = ["RCP26", "RCP45", "RCP85"]

thisdict1 = {
  "RCP2.6": "blue",
  "RCP4.5": "green",
  "RCP8.5": "red"}

thisdict2 = {
  "RCP2.6": 100,
  "RCP4.5": 300,
  "RCP8.5": 500}

#class_colours = ['r','b','g']

#for RCP in thisdict:
#for RCP in np.unique(RCPs):
    #ix = np.where(group == g)
    
averageTMP26 = []
averageTMP45 = []
averageTMP85 = []
averagePCP26 = []
averagePCP45 = []
averagePCP85 = []
RCP26 = []
RCP45 = []
RCP85 = []

for i in range (0, np.size(RCPs)) :
    if RCPs[i] == 2.6:
    #ax.scatter(averageTMP, averagePCP, s= RCPs*50, c =thisdict[RCP], marker='o', alpha=0.3, cmap='viridis', label=thisdict[RCP])
    #ax.scatter(averageTMP, averagePCP, s = RCPs*50, c= RCPs, marker='o', alpha=0.3, cmap='viridis', edgecolors='none')
        averageTMP26.append(averageTMP[i])
        averagePCP26.append(averagePCP[i])
        RCP26.append(RCPs[i])
    
    elif RCPs[i] == 4.5:
        averageTMP45.append(averageTMP[i])
        averagePCP45.append(averagePCP[i])
        RCP45.append(RCPs[i])
        
    elif RCPs[i] == 8.5:
        averageTMP85.append(averageTMP[i])
        averagePCP85.append(averagePCP[i])
        RCP85.append(RCPs[i])
        
        
#for area in thisdict1:
    #plt.scatter([], [], c='k', alpha=0.3, s=area,
                #label=str(area) + ' km$^2$')
#plt.colorbar()# show color scale


ax.scatter(averageTMP26, averagePCP26, s = 100, c='b' , marker='o', alpha=0.3, cmap='viridis', edgecolors='none', label='RCP2.6')
ax.scatter(averageTMP45, averagePCP45, s = 300, c='g' , marker='o', alpha=0.3, cmap='viridis', edgecolors='none', label='RCP4.5')
ax.scatter(averageTMP85, averagePCP85, s = 500, c='r' , marker='o', alpha=0.3, cmap='viridis', edgecolors='none', label='RCP8.5')

ax.set_xlabel("Temeprature (C)")
ax.set_ylabel("Precipitaion (mm)")
#legend1 = ax.legend( RCPs , title="RCPs")

#class_colours = ['r','b','g']
#recs = []
#for i in range(0,len(class_colours)):
#   recs.append(mpatches.Rectangle((0,0),1,1,fc=class_colours[i]))
#plt.legend(recs,class_colours)

plt.legend(loc='lower right', ncol=3)
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.set_ylim(bottom=-5)
plt.show()

# %%
import numpy as np
np.random.seed(19680801)
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
for color in ['tab:blue', 'tab:orange', 'tab:green']:
    n = 750
    x, y = np.random.rand(2, n)
    scale = 200.0 * np.random.rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()
