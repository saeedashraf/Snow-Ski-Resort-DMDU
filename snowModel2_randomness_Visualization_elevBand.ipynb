# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.integrate import simps
from numpy import trapz
from decimal import Decimal, ROUND_DOWN, ROUND_UP

# %%
# Resort6elevation bands
df4_b1 = pd.read_csv('data_out_snow_randomness_villars-diablerets_elev_band/snowSeason_n_band1_1339.csv')
df4_b2 = pd.read_csv('data_out_snow_randomness_villars-diablerets_elev_band/snowSeason_n_band2_1882.csv')
df4_b3 = pd.read_csv('data_out_snow_randomness_villars-diablerets_elev_band/snowSeason_n_band3_2000.csv')
df4_b4 = pd.read_csv('data_out_snow_randomness_villars-diablerets_elev_band/snowSeason_n_band4_2500.csv')

# Resort6 elevation bands
df6_b1 = pd.read_csv('data_out_snow_randomness_davos_elev_band/snowSeason_n_band1_1564.csv')
df6_b2 = pd.read_csv('data_out_snow_randomness_davos_elev_band/snowSeason_n_band2_2141.csv')
df6_b3 = pd.read_csv('data_out_snow_randomness_davos_elev_band/snowSeason_n_band3_2584.csv')

# %%
# Setting the columns and row maxium display
pd.set_option('display.max_columns',69)

# %%
df4_b1Columns= df4_b1.columns
df4_b2Columns= df4_b2.columns
df4_b3Columns= df4_b3.columns
df4_b4Columns= df4_b4.columns
df6_b1Columns= df6_b1.columns
df6_b2Columns= df6_b2.columns
df6_b3Columns= df6_b3.columns

# %%
df4_b1Columns
# Out:
# Index(['DATE', 'isOverSnowTotal_sc_26_1', 'isOverSnowTotal_sc_26_2',
#        'isOverSnowTotal_sc_26_3', 'isOverSnowTotal_sc_26_4',
#        'isOverSnowTotal_sc_26_5', 'isOverSnowTotal_sc_26_6',
#        'isOverSnowTotal_sc_26_7', 'isOverSnowTotal_sc_26_8',
#        'isOverSnowTotal_sc_26_9', 'isOverSnowTotal_sc_26_10',
#        'isOverSnowTotal_sc_26_11', 'isOverSnowTotal_sc_26_12',
#        'isOverSnowTotal_sc_45_1', 'isOverSnowTotal_sc_45_2',
#        'isOverSnowTotal_sc_45_3', 'isOverSnowTotal_sc_45_4',
#        'isOverSnowTotal_sc_45_5', 'isOverSnowTotal_sc_45_6',
#        'isOverSnowTotal_sc_45_7', 'isOverSnowTotal_sc_45_8',
#        'isOverSnowTotal_sc_45_9', 'isOverSnowTotal_sc_45_10',
#        'isOverSnowTotal_sc_45_11', 'isOverSnowTotal_sc_45_12',
#        'isOverSnowTotal_sc_45_13', 'isOverSnowTotal_sc_45_14',
#        'isOverSnowTotal_sc_45_15', 'isOverSnowTotal_sc_45_16',
#        'isOverSnowTotal_sc_45_17', 'isOverSnowTotal_sc_45_18',
# ...

# %%
filt1 = df4_b1.columns.str.contains('sc_26')
filt2 = df4_b1.columns.str.contains('sc_45')
filt3 = df4_b1.columns.str.contains('sc_85')

filt4 = df4_b2.columns.str.contains('sc_26')
filt5 = df4_b2.columns.str.contains('sc_45')
filt6 = df4_b2.columns.str.contains('sc_85')

filt7 = df4_b3.columns.str.contains('sc_26')
filt8 = df4_b3.columns.str.contains('sc_45')
filt9 = df4_b3.columns.str.contains('sc_85')

filt10 = df4_b4.columns.str.contains('sc_26')
filt11 = df4_b4.columns.str.contains('sc_45')
filt12 = df4_b4.columns.str.contains('sc_85')

filt13 = df6_b1.columns.str.contains('sc_26')
filt14 = df6_b1.columns.str.contains('sc_45')
filt15 = df6_b1.columns.str.contains('sc_85')

filt16 = df6_b2.columns.str.contains('sc_26')
filt17 = df6_b2.columns.str.contains('sc_45')
filt18 = df6_b2.columns.str.contains('sc_85')

filt19 = df6_b3.columns.str.contains('sc_26')
filt20 = df6_b3.columns.str.contains('sc_45')
filt21 = df6_b3.columns.str.contains('sc_85')

# %%
df4_b1RCP26 = df4_b1.loc[:, filt1]
df4_b1RCP45 = df4_b1.loc[:, filt2]
df4_b1RCP85 = df4_b1.loc[:, filt3]

df4_b2RCP26 = df4_b2.loc[:, filt4]
df4_b2RCP45 = df4_b2.loc[:, filt5]
df4_b2RCP85 = df4_b2.loc[:, filt6]

df4_b3RCP26 = df4_b3.loc[:, filt7]
df4_b3RCP45 = df4_b3.loc[:, filt8]
df4_b3RCP85 = df4_b3.loc[:, filt9]

df4_b4RCP26 = df4_b4.loc[:, filt10]
df4_b4RCP45 = df4_b4.loc[:, filt11]
df4_b4RCP85 = df4_b4.loc[:, filt12]

df6_b1RCP26 = df6_b1.loc[:, filt13]
df6_b1RCP45 = df6_b1.loc[:, filt14]
df6_b1RCP85 = df6_b1.loc[:, filt15]

df6_b2RCP26 = df6_b2.loc[:, filt16]
df6_b2RCP45 = df6_b2.loc[:, filt17]
df6_b2RCP85 = df6_b2.loc[:, filt18]

df6_b3RCP26 = df6_b3.loc[:, filt16]
df6_b3RCP45 = df6_b3.loc[:, filt17]
df6_b3RCP85 = df6_b3.loc[:, filt18]

# %%
df4_b1RCP26Columns= df4_b1RCP26.columns
df4_b2RCP26Columns= df4_b2RCP26.columns
df4_b3RCP26Columns= df4_b3RCP26.columns
df4_b4RCP26Columns= df4_b4RCP26.columns
df6_b1RCP26Columns= df6_b1RCP26.columns
df6_b2RCP26Columns= df6_b2RCP26.columns
df6_b3RCP26Columns= df6_b3RCP26.columns


df4_b1RCP45Columns= df4_b1RCP45.columns
df4_b2RCP45Columns= df4_b2RCP45.columns
df4_b3RCP45Columns= df4_b3RCP45.columns
df4_b4RCP45Columns= df4_b4RCP45.columns
df6_b1RCP45Columns= df6_b1RCP45.columns
df6_b2RCP45Columns= df6_b2RCP45.columns
df6_b3RCP45Columns= df6_b3RCP45.columns


df4_b1RCP85Columns= df4_b1RCP85.columns
df4_b2RCP85Columns= df4_b2RCP85.columns
df4_b3RCP85Columns= df4_b3RCP85.columns
df4_b4RCP85Columns= df4_b4RCP85.columns
df6_b1RCP85Columns= df6_b1RCP85.columns
df6_b2RCP85Columns= df6_b2RCP85.columns
df6_b3RCP85Columns= df6_b3RCP85.columns

# %%
dfsColumns = [df4_b1Columns, df4_b2Columns, df4_b3Columns, df4_b4Columns, df6_b1Columns, df6_b2Columns, df6_b3Columns]
dfs = [df4_b1, df4_b2, df4_b3, df4_b4, df6_b1, df6_b2, df6_b3]

# %%
def generate_plot_all(df, dfColumns, m, n, colorLines):
    for i in range (1 , len(dfColumns), 1):
        #res1_sc1 = df[dfColumns[i]]
        axs[m,n].plot(x_axis, df[dfColumns[i]], color=colorLines, linestyle = '--', alpha=0.02)
        return
        
def generate_plot_max_min(df, m, n, BotYaxis, TopYaxis,fig_Title, fig_X_Lable, fig_Y_Lable):
    
    axs[m,n].axhline(y=100, color='red')
    axs[m,n].set_ylim(bottom=BotYaxis, top =TopYaxis)
    axs[m,n].set_title(fig_Title)
    axs[m,n].set_xlabel(fig_X_Lable)
    axs[m,n].set_ylabel(fig_Y_Lable)
        
        
    axs[m,n].plot(x_axis, df.max(axis=1), color='blue', linestyle = '--', alpha=0.8)
    axs[m,n].plot(x_axis, df.min(axis=1), color='red', linestyle = '--', alpha=0.8)
    axs[m,n].fill_between(x_axis[0:118], df.max(axis=1), df.min(axis=1), alpha=0.15, color='C1')
        #plt.xticks(np.arange(1981, 2099, step=20))
         #Possible Colors: color='#DBFF33',
    return

# %% [markdown]
# ### Analysis 1 Villars-diablerets RCP2.6

# %%
#fig, (ax1 , ax2) = plt.subplots(1, 2)
m = 2
n = 2
fig, axs = plt.subplots(m, n, figsize=(15,15))

y = 118
#x_axis = np.arange(y)
x_axis = np.arange(1981, 2099, step=1)
#plt.style.use('seaborn')

RCP ="RCP2.6"
generate_plot_max_min(df4_b1RCP26,0,0,0,225, 'Villars-diablerets_b1 1339m {}'.format(RCP),"","Days with good snow condition")
generate_plot_max_min(df4_b2RCP26,0,1,0,225, 'Villars-diablerets_b2 1882m {}'.format(RCP),"","")
generate_plot_max_min(df4_b3RCP26,1,0,0,225, 'Villars-diablerets_b3 2000m{}'.format(RCP),"","Days with good snow condition")
generate_plot_max_min(df4_b4RCP26,1,1,0,300, 'Villars-diablerets_b4 2500m{}'.format(RCP),"","")

plt.show()

# %% [markdown]
# ### Analysis 2 Villars-diablerets RCP4.5

# %%
#fig, (ax1 , ax2) = plt.subplots(1, 2)
m = 2
n = 2
fig, axs = plt.subplots(m, n, figsize=(15,15))

y = 118
#x_axis = np.arange(y)
x_axis = np.arange(1981, 2099, step=1)
#plt.style.use('seaborn')

RCP ="RCP4.5"
generate_plot_max_min(df4_b1RCP45,0,0,0,225, 'Villars-diablerets_b1 1339m {}'.format(RCP),"","Days with good snow condition")
generate_plot_max_min(df4_b2RCP45,0,1,0,225, 'Villars-diablerets_b2 1882m {}'.format(RCP),"","")
generate_plot_max_min(df4_b3RCP45,1,0,0,225, 'Villars-diablerets_b3 2000m{}'.format(RCP),"","Days with good snow condition")
generate_plot_max_min(df4_b4RCP45,1,1,0,300, 'Villars-diablerets_b4 2500m{}'.format(RCP),"","")

plt.show()

# %% [markdown]
# ### Analysis 3 Villars-diablerets RCP8.5

# %%
#fig, (ax1 , ax2) = plt.subplots(1, 2)
m = 2
n = 2
fig, axs = plt.subplots(m, n, figsize=(15,15))

y = 118
#x_axis = np.arange(y)
x_axis = np.arange(1981, 2099, step=1)
#plt.style.use('seaborn')

RCP ="RCP8.5"
generate_plot_max_min(df4_b1RCP85,0,0,0,225, 'Villars-diablerets_b1 1339m {}'.format(RCP),"","Days with good snow condition")
generate_plot_max_min(df4_b2RCP85,0,1,0,225, 'Villars-diablerets_b2 1882m {}'.format(RCP),"","")
generate_plot_max_min(df4_b3RCP85,1,0,0,225, 'Villars-diablerets_b3 2000m{}'.format(RCP),"","Days with good snow condition")
generate_plot_max_min(df4_b4RCP85,1,1,0,300, 'Villars-diablerets_b4 2500m{}'.format(RCP),"","")

plt.show()

# %% [markdown]
# ### Analysis 4 Davos RCP2.6

# %%
#fig, (ax1 , ax2) = plt.subplots(1, 2)
m = 2
n = 2
fig, axs = plt.subplots(m, n, figsize=(15,15))

y = 118
#x_axis = np.arange(y)
x_axis = np.arange(1981, 2099, step=1)
#plt.style.use('seaborn')

RCP ="RCP2.6"
generate_plot_max_min(df6_b1RCP26,0,0,0,225, 'Davos_b1 1564m {}'.format(RCP),"","Days with good snow condition")
generate_plot_max_min(df6_b2RCP26,0,1,0,225, 'Davos_b2 2141m {}'.format(RCP),"","")
generate_plot_max_min(df6_b3RCP26,1,0,0,225, 'Davos_b3 2584m {}'.format(RCP),"","Days with good snow condition")

plt.show()

# %% [markdown]
# ### Analysis 5 Davos RCP4.5

# %%
#fig, (ax1 , ax2) = plt.subplots(1, 2)
m = 2
n = 2
fig, axs = plt.subplots(m, n, figsize=(15,15))

y = 118
#x_axis = np.arange(y)
x_axis = np.arange(1981, 2099, step=1)
#plt.style.use('seaborn')

RCP ="RCP4.5"
generate_plot_max_min(df6_b1RCP45,0,0,0,225, 'Davos_b1 1564m {}'.format(RCP),"","Days with good snow condition")
generate_plot_max_min(df6_b2RCP45,0,1,0,225, 'Davos_b2 2141m {}'.format(RCP),"","")
generate_plot_max_min(df6_b3RCP45,1,0,0,225, 'Davos_b3 2584m {}'.format(RCP),"","Days with good snow condition")

plt.show()

# %% [markdown]
# ### Analysis 6 Davos RCP8.5

# %%
#fig, (ax1 , ax2) = plt.subplots(1, 2)
m = 2
n = 2
fig, axs = plt.subplots(m, n, figsize=(15,15))

y = 118
#x_axis = np.arange(y)
x_axis = np.arange(1981, 2099, step=1)
#plt.style.use('seaborn')

RCP ="RCP8.5"
generate_plot_max_min(df6_b1RCP85,0,0,0,225, 'Davos_b1 1564m {}'.format(RCP),"","Days with good snow condition")
generate_plot_max_min(df6_b2RCP85,0,1,0,225, 'Davos_b2 2141m {}'.format(RCP),"","")
generate_plot_max_min(df6_b3RCP85,1,0,0,225, 'Davos_b3 2584m {}'.format(RCP),"","Days with good snow condition")

plt.show()
